# %%
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
from random import random
import matplotlib.pyplot as plt

# %%
from scipy import stats
import numpy as np

threshold = 3
z = np.abs(stats.zscore(data1))
clean_data1 = data1[(z<3).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-e8738f6f64df> in <module>
#       6 clean_data1 = data1[(z<3).all(axis=1)]
#       7 len(data1)
# ----> 8 clean_data1.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data1 = series[['ClaimDate_delta','ClaimAmount']]
sns.lmplot(x='ClaimDate_delta',y='ClaimAmount',data=clean_data1)

# %%
sns.catplot(x="ClaimDate_delta",y="ClaimAmount",data=clean_data1)

# %%
# contrived dataset
y = [x + random() for x in range(1, 100)]
x = [x for x in range(1,100)]
data= [x + random() for x in range(1, 100)]
# fit model
model = ARIMA(data, order=(1, 1, 1))
model_fit = model.fit(disp=True)
# make prediction
yhat = model_fit.predict(99, typ='levels')
print(yhat)
# Out:
# [100.65174922]

# %%
# AR example
from statsmodels.tsa.ar_model import AR
from random import random
# contrived dataset
data = [x + random() for x in range(1, 100)]
# fit model
model = AR(data)
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(len(data), len(data))

print(yhat)
# Out:
# [100.65723768]

# %%
	
# HWES example
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from random import random
# contrived dataset
data = [x + random() for x in range(1, 100)]
# fit model
model = ExponentialSmoothing(data)
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# [99.40420023]

# %%
data
# Out:
#                  ClaimAmount
# ClaimDate_delta
# 96                      8456
# 96                      6622
# 87                       211
# 91                       146
# 91                      3691
# ...                      ...
# 77                        67
# 71                        34
# 100                      124
# 79                        63
# 68                        22
#
# [20627 rows x 1 columns]

# %%
from pandas import read_csv
import pandas as pd
from matplotlib import pyplot
series = pd.read_csv('insurance-claim-forecast/many_clean_data.csv', header=0, index_col=0)
data = series[['ClaimDate_delta','ClaimAmount']]
data = data.set_index('ClaimDate_delta')
series.ClaimAmount.plot(figsize=(30,5))
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

#series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0)
plot_acf(data,lags=5)
pyplot.show()

# %%
plot_pacf(data, lags=5)
pyplot.show()

# %% [markdown]
# https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/
#
# https://www.statsmodels.org/stable/examples/index.html#stats
#
# https://www.kaggle.com/c/ClaimPredictionChallenge
